# %% [markdown]
# # The President Trump Tweets and Analysis

# %% [markdown]
# #Sentiment Analysis: Positive, Negative and Neutral
# #Random Forest:
# "To say it in simple words: Random forest builds multiple decision trees and merges them together to get a more accurate and stable prediction. One big advantage of random forest is, that it"
# https://towardsdatascience.com/the-random-forest-algorithm-d457d499ffcd

# %%
import pandas as pd # To hande data
import numpy as np # To compute numbers
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, \
precision_score, recall_score
import tweepy # To consume Twitter's api
from textblob import TextBlob
import re
# plotting and  visualizaion
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 1. Getting data using a scrapper provided

# %% [markdown]
# by http://www.trumptwitterarchive.com  or https://github.com/bpb27/twitter_scraping

# %%
# Through Selenium Python API you can access all functionalities of Selenium WebDriver in an intuitive way.
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime

# %%
user = 'realdonaldtrump'
start = datetime.datetime(2016, 11, 1)
end = datetime.datetime(2019, 2, 17)

# %%
#Run Chrome Driver
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome(r'C:\Users\sarin_000\Desktop\ds_projects\ga_repo\chromedriver.exe')

# %%
# Get data from twitter
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item'
user = user.lower()
ids = []

def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?f=tweets&vertical=default&q=from%3A'
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))

        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)


try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))
except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
driver.close()
# Out:
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-01%20until%3A2016-11-02include%3Aretweets&src=typd
# 2016-11-01
# scrolling down to load more tweets
# 13 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-02%20until%3A2016-11-03include%3Aretweets&src=typd
# 2016-11-02
# scrolling down to load more tweets
# 14 tweets found, 13 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-03%20until%3A2016-11-04include%3Aretweets&src=typd
# 2016-11-03
# 8 tweets found, 27 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-04%20until%3A2016-11-05include%3Aretweets&src=typd
# 2016-11-04
# scrolling down to load more tweets
# 12 tweets found, 35 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-05%20until%3A2016-11-06include%3Aretweets&src=typd
# 2016-11-05
# 9 tweets found, 47 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-06%20until%3A2016-11-07include%3Aretweets&src=typd
# 2016-11-06
# 8 tweets found, 56 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-07%20until%3A2016-11-08include%3Aretweets&src=typd
# 2016-11-07
# scrolling down to load more tweets
# 13 tweets found, 64 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-08%20until%3A2016-11-09include%3Aretweets&src=typd
# 2016-11-08
# scrolling down to load more tweets
# 13 tweets found, 77 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-09%20until%3A2016-11-10include%3Aretweets&src=typd
# 2016-11-09
# 2 tweets found, 90 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-10%20until%3A2016-11-11include%3Aretweets&src=typd
# 2016-11-10
# 1 tweets found, 92 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-11%20until%3A2016-11-12include%3Aretweets&src=typd
# 2016-11-11
# 5 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-12%20until%3A2016-11-13include%3Aretweets&src=typd
# 2016-11-12
# 1 tweets found, 98 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-13%20until%3A2016-11-14include%3Aretweets&src=typd
# 2016-11-13
# 8 tweets found, 99 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-14%20until%3A2016-11-15include%3Aretweets&src=typd
# 2016-11-14
# 0 tweets found, 107 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-15%20until%3A2016-11-16include%3Aretweets&src=typd
# 2016-11-15
# 2 tweets found, 107 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-16%20until%3A2016-11-17include%3Aretweets&src=typd
# 2016-11-16
# 5 tweets found, 109 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-17%20until%3A2016-11-18include%3Aretweets&src=typd
# 2016-11-17
# 1 tweets found, 114 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-18%20until%3A2016-11-19include%3Aretweets&src=typd
# 2016-11-18
# 3 tweets found, 115 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-19%20until%3A2016-11-20include%3Aretweets&src=typd
# 2016-11-19
# 4 tweets found, 118 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-20%20until%3A2016-11-21include%3Aretweets&src=typd
# 2016-11-20
# 5 tweets found, 122 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-21%20until%3A2016-11-22include%3Aretweets&src=typd
# 2016-11-21
# 1 tweets found, 127 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-22%20until%3A2016-11-23include%3Aretweets&src=typd
# 2016-11-22
# scrolling down to load more tweets
# 10 tweets found, 128 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-23%20until%3A2016-11-24include%3Aretweets&src=typd
# 2016-11-23
# 1 tweets found, 138 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-24%20until%3A2016-11-25include%3Aretweets&src=typd
# 2016-11-24
# 3 tweets found, 139 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-25%20until%3A2016-11-26include%3Aretweets&src=typd
# 2016-11-25
# 0 tweets found, 142 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-26%20until%3A2016-11-27include%3Aretweets&src=typd
# 2016-11-26
# 1 tweets found, 142 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-27%20until%3A2016-11-28include%3Aretweets&src=typd
# 2016-11-27
# scrolling down to load more tweets
# 12 tweets found, 143 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-28%20until%3A2016-11-29include%3Aretweets&src=typd
# 2016-11-28
# 3 tweets found, 155 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-29%20until%3A2016-11-30include%3Aretweets&src=typd
# 2016-11-29
# scrolling down to load more tweets
# 11 tweets found, 158 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-11-30%20until%3A2016-12-01include%3Aretweets&src=typd
# 2016-11-30
# scrolling down to load more tweets
# 10 tweets found, 169 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-01%20until%3A2016-12-02include%3Aretweets&src=typd
# 2016-12-01
# 4 tweets found, 179 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-02%20until%3A2016-12-03include%3Aretweets&src=typd
# 2016-12-02
# 1 tweets found, 183 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-03%20until%3A2016-12-04include%3Aretweets&src=typd
# 2016-12-03
# 6 tweets found, 184 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-04%20until%3A2016-12-05include%3Aretweets&src=typd
# 2016-12-04
# scrolling down to load more tweets
# 11 tweets found, 190 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-05%20until%3A2016-12-06include%3Aretweets&src=typd
# 2016-12-05
# 3 tweets found, 201 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-06%20until%3A2016-12-07include%3Aretweets&src=typd
# 2016-12-06
# 5 tweets found, 204 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-07%20until%3A2016-12-08include%3Aretweets&src=typd
# 2016-12-07
# 4 tweets found, 209 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-08%20until%3A2016-12-09include%3Aretweets&src=typd
# 2016-12-08
# 5 tweets found, 213 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-09%20until%3A2016-12-10include%3Aretweets&src=typd
# 2016-12-09
# 3 tweets found, 218 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-10%20until%3A2016-12-11include%3Aretweets&src=typd
# 2016-12-10
# 7 tweets found, 221 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-11%20until%3A2016-12-12include%3Aretweets&src=typd
# 2016-12-11
# 4 tweets found, 228 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-12%20until%3A2016-12-13include%3Aretweets&src=typd
# 2016-12-12
# 7 tweets found, 232 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-13%20until%3A2016-12-14include%3Aretweets&src=typd
# 2016-12-13
# 8 tweets found, 239 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-14%20until%3A2016-12-15include%3Aretweets&src=typd
# 2016-12-14
# 2 tweets found, 247 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-15%20until%3A2016-12-16include%3Aretweets&src=typd
# 2016-12-15
# 5 tweets found, 249 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-16%20until%3A2016-12-17include%3Aretweets&src=typd
# 2016-12-16
# 4 tweets found, 254 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-17%20until%3A2016-12-18include%3Aretweets&src=typd
# 2016-12-17
# 5 tweets found, 258 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-18%20until%3A2016-12-19include%3Aretweets&src=typd
# 2016-12-18
# 3 tweets found, 263 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-19%20until%3A2016-12-20include%3Aretweets&src=typd
# 2016-12-19
# 2 tweets found, 266 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-20%20until%3A2016-12-21include%3Aretweets&src=typd
# 2016-12-20
# 5 tweets found, 268 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-21%20until%3A2016-12-22include%3Aretweets&src=typd
# 2016-12-21
# 3 tweets found, 273 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-22%20until%3A2016-12-23include%3Aretweets&src=typd
# 2016-12-22
# 5 tweets found, 276 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-23%20until%3A2016-12-24include%3Aretweets&src=typd
# 2016-12-23
# 6 tweets found, 281 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-24%20until%3A2016-12-25include%3Aretweets&src=typd
# 2016-12-24
# 4 tweets found, 287 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-25%20until%3A2016-12-26include%3Aretweets&src=typd
# 2016-12-25
# 2 tweets found, 291 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-26%20until%3A2016-12-27include%3Aretweets&src=typd
# 2016-12-26
# 3 tweets found, 293 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-27%20until%3A2016-12-28include%3Aretweets&src=typd
# 2016-12-27
# 3 tweets found, 296 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-28%20until%3A2016-12-29include%3Aretweets&src=typd
# 2016-12-28
# 5 tweets found, 299 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-29%20until%3A2016-12-30include%3Aretweets&src=typd
# 2016-12-29
# 1 tweets found, 304 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-30%20until%3A2016-12-31include%3Aretweets&src=typd
# 2016-12-30
# 3 tweets found, 305 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2016-12-31%20until%3A2017-01-01include%3Aretweets&src=typd
# 2016-12-31
# 2 tweets found, 308 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-01%20until%3A2017-01-02include%3Aretweets&src=typd
# 2017-01-01
# 1 tweets found, 310 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-02%20until%3A2017-01-03include%3Aretweets&src=typd
# 2017-01-02
# 7 tweets found, 311 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-03%20until%3A2017-01-04include%3Aretweets&src=typd
# 2017-01-03
# scrolling down to load more tweets
# 10 tweets found, 318 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-04%20until%3A2017-01-05include%3Aretweets&src=typd
# 2017-01-04
# scrolling down to load more tweets
# 10 tweets found, 328 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-05%20until%3A2017-01-06include%3Aretweets&src=typd
# 2017-01-05
# 6 tweets found, 338 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-06%20until%3A2017-01-07include%3Aretweets&src=typd
# 2017-01-06
# scrolling down to load more tweets
# 12 tweets found, 344 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-07%20until%3A2017-01-08include%3Aretweets&src=typd
# 2017-01-07
# 8 tweets found, 356 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-08%20until%3A2017-01-09include%3Aretweets&src=typd
# 2017-01-08
# 5 tweets found, 364 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-09%20until%3A2017-01-10include%3Aretweets&src=typd
# 2017-01-09
# 8 tweets found, 369 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-10%20until%3A2017-01-11include%3Aretweets&src=typd
# 2017-01-10
# 4 tweets found, 377 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-11%20until%3A2017-01-12include%3Aretweets&src=typd
# 2017-01-11
# 6 tweets found, 381 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-12%20until%3A2017-01-13include%3Aretweets&src=typd
# 2017-01-12
# 6 tweets found, 387 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-13%20until%3A2017-01-14include%3Aretweets&src=typd
# 2017-01-13
# 8 tweets found, 393 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-14%20until%3A2017-01-15include%3Aretweets&src=typd
# 2017-01-14
# 3 tweets found, 401 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-15%20until%3A2017-01-16include%3Aretweets&src=typd
# 2017-01-15
# 8 tweets found, 404 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-16%20until%3A2017-01-17include%3Aretweets&src=typd
# 2017-01-16
# 3 tweets found, 412 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-17%20until%3A2017-01-18include%3Aretweets&src=typd
# 2017-01-17
# scrolling down to load more tweets
# 11 tweets found, 415 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-18%20until%3A2017-01-19include%3Aretweets&src=typd
# 2017-01-18
# 8 tweets found, 426 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-19%20until%3A2017-01-20include%3Aretweets&src=typd
# 2017-01-19
# 8 tweets found, 434 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-20%20until%3A2017-01-21include%3Aretweets&src=typd
# 2017-01-20
# scrolling down to load more tweets
# 13 tweets found, 442 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-21%20until%3A2017-01-22include%3Aretweets&src=typd
# 2017-01-21
# 2 tweets found, 455 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-22%20until%3A2017-01-23include%3Aretweets&src=typd
# 2017-01-22
# 4 tweets found, 457 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-23%20until%3A2017-01-24include%3Aretweets&src=typd
# 2017-01-23
# 1 tweets found, 461 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-24%20until%3A2017-01-25include%3Aretweets&src=typd
# 2017-01-24
# 4 tweets found, 462 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-25%20until%3A2017-01-26include%3Aretweets&src=typd
# 2017-01-25
# 8 tweets found, 466 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-26%20until%3A2017-01-27include%3Aretweets&src=typd
# 2017-01-26
# scrolling down to load more tweets
# 10 tweets found, 474 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-27%20until%3A2017-01-28include%3Aretweets&src=typd
# 2017-01-27
# 7 tweets found, 484 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-28%20until%3A2017-01-29include%3Aretweets&src=typd
# 2017-01-28
# 4 tweets found, 491 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-29%20until%3A2017-01-30include%3Aretweets&src=typd
# 2017-01-29
# 7 tweets found, 495 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-30%20until%3A2017-01-31include%3Aretweets&src=typd
# 2017-01-30
# 7 tweets found, 502 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-01-31%20until%3A2017-02-01include%3Aretweets&src=typd
# 2017-01-31
# 3 tweets found, 509 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-01%20until%3A2017-02-02include%3Aretweets&src=typd
# 2017-02-01
# 4 tweets found, 512 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-02%20until%3A2017-02-03include%3Aretweets&src=typd
# 2017-02-02
# 8 tweets found, 516 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-03%20until%3A2017-02-04include%3Aretweets&src=typd
# 2017-02-03
# 7 tweets found, 524 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-04%20until%3A2017-02-05include%3Aretweets&src=typd
# 2017-02-04
# 9 tweets found, 531 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-05%20until%3A2017-02-06include%3Aretweets&src=typd
# 2017-02-05
# 5 tweets found, 540 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-06%20until%3A2017-02-07include%3Aretweets&src=typd
# 2017-02-06
# 5 tweets found, 545 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-07%20until%3A2017-02-08include%3Aretweets&src=typd
# 2017-02-07
# 4 tweets found, 550 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-08%20until%3A2017-02-09include%3Aretweets&src=typd
# 2017-02-08
# scrolling down to load more tweets
# 11 tweets found, 554 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-09%20until%3A2017-02-10include%3Aretweets&src=typd
# 2017-02-09
# 8 tweets found, 565 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-10%20until%3A2017-02-11include%3Aretweets&src=typd
# 2017-02-10
# 3 tweets found, 573 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-11%20until%3A2017-02-12include%3Aretweets&src=typd
# 2017-02-11
# 8 tweets found, 576 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-12%20until%3A2017-02-13include%3Aretweets&src=typd
# 2017-02-12
# 8 tweets found, 584 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-13%20until%3A2017-02-14include%3Aretweets&src=typd
# 2017-02-13
# 3 tweets found, 592 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-14%20until%3A2017-02-15include%3Aretweets&src=typd
# 2017-02-14
# 6 tweets found, 595 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-15%20until%3A2017-02-16include%3Aretweets&src=typd
# 2017-02-15
# scrolling down to load more tweets
# 11 tweets found, 601 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-16%20until%3A2017-02-17include%3Aretweets&src=typd
# 2017-02-16
# 6 tweets found, 612 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-17%20until%3A2017-02-18include%3Aretweets&src=typd
# 2017-02-17
# 7 tweets found, 618 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-18%20until%3A2017-02-19include%3Aretweets&src=typd
# 2017-02-18
# 3 tweets found, 625 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-19%20until%3A2017-02-20include%3Aretweets&src=typd
# 2017-02-19
# 1 tweets found, 628 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-20%20until%3A2017-02-21include%3Aretweets&src=typd
# 2017-02-20
# 3 tweets found, 629 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-21%20until%3A2017-02-22include%3Aretweets&src=typd
# 2017-02-21
# 3 tweets found, 632 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-22%20until%3A2017-02-23include%3Aretweets&src=typd
# 2017-02-22
# 2 tweets found, 635 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-23%20until%3A2017-02-24include%3Aretweets&src=typd
# 2017-02-23
# 1 tweets found, 637 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-24%20until%3A2017-02-25include%3Aretweets&src=typd
# 2017-02-24
# 6 tweets found, 638 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-25%20until%3A2017-02-26include%3Aretweets&src=typd
# 2017-02-25
# 7 tweets found, 644 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-26%20until%3A2017-02-27include%3Aretweets&src=typd
# 2017-02-26
# 4 tweets found, 651 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-27%20until%3A2017-02-28include%3Aretweets&src=typd
# 2017-02-27
# 2 tweets found, 655 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-02-28%20until%3A2017-03-01include%3Aretweets&src=typd
# 2017-02-28
# 1 tweets found, 657 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-01%20until%3A2017-03-02include%3Aretweets&src=typd
# 2017-03-01
# 3 tweets found, 658 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-02%20until%3A2017-03-03include%3Aretweets&src=typd
# 2017-03-02
# 1 tweets found, 661 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-03%20until%3A2017-03-04include%3Aretweets&src=typd
# 2017-03-03
# scrolling down to load more tweets
# 11 tweets found, 662 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-04%20until%3A2017-03-05include%3Aretweets&src=typd
# 2017-03-04
# 7 tweets found, 673 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-05%20until%3A2017-03-06include%3Aretweets&src=typd
# 2017-03-05
# 3 tweets found, 680 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-06%20until%3A2017-03-07include%3Aretweets&src=typd
# 2017-03-06
# 3 tweets found, 683 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-07%20until%3A2017-03-08include%3Aretweets&src=typd
# 2017-03-07
# 8 tweets found, 686 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-08%20until%3A2017-03-09include%3Aretweets&src=typd
# 2017-03-08
# 6 tweets found, 694 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-09%20until%3A2017-03-10include%3Aretweets&src=typd
# 2017-03-09
# 3 tweets found, 700 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-10%20until%3A2017-03-11include%3Aretweets&src=typd
# 2017-03-10
# 1 tweets found, 703 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-11%20until%3A2017-03-12include%3Aretweets&src=typd
# 2017-03-11
# 1 tweets found, 704 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-12%20until%3A2017-03-13include%3Aretweets&src=typd
# 2017-03-12
# 0 tweets found, 705 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-13%20until%3A2017-03-14include%3Aretweets&src=typd
# 2017-03-13
# 5 tweets found, 705 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-14%20until%3A2017-03-15include%3Aretweets&src=typd
# 2017-03-14
# 2 tweets found, 710 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-15%20until%3A2017-03-16include%3Aretweets&src=typd
# 2017-03-15
# 7 tweets found, 712 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-16%20until%3A2017-03-17include%3Aretweets&src=typd
# 2017-03-16
# 6 tweets found, 719 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-17%20until%3A2017-03-18include%3Aretweets&src=typd
# 2017-03-17
# 4 tweets found, 725 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-18%20until%3A2017-03-19include%3Aretweets&src=typd
# 2017-03-18
# 2 tweets found, 729 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-19%20until%3A2017-03-20include%3Aretweets&src=typd
# 2017-03-19
# 1 tweets found, 731 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-20%20until%3A2017-03-21include%3Aretweets&src=typd
# 2017-03-20
# 7 tweets found, 732 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-21%20until%3A2017-03-22include%3Aretweets&src=typd
# 2017-03-21
# 4 tweets found, 739 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-22%20until%3A2017-03-23include%3Aretweets&src=typd
# 2017-03-22
# 1 tweets found, 743 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-23%20until%3A2017-03-24include%3Aretweets&src=typd
# 2017-03-23
# 5 tweets found, 744 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-24%20until%3A2017-03-25include%3Aretweets&src=typd
# 2017-03-24
# 4 tweets found, 749 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-25%20until%3A2017-03-26include%3Aretweets&src=typd
# 2017-03-25
# 4 tweets found, 753 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-26%20until%3A2017-03-27include%3Aretweets&src=typd
# 2017-03-26
# 1 tweets found, 757 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-27%20until%3A2017-03-28include%3Aretweets&src=typd
# 2017-03-27
# 1 tweets found, 758 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-28%20until%3A2017-03-29include%3Aretweets&src=typd
# 2017-03-28
# scrolling down to load more tweets
# 10 tweets found, 759 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-29%20until%3A2017-03-30include%3Aretweets&src=typd
# 2017-03-29
# 4 tweets found, 769 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-30%20until%3A2017-03-31include%3Aretweets&src=typd
# 2017-03-30
# 8 tweets found, 773 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-03-31%20until%3A2017-04-01include%3Aretweets&src=typd
# 2017-03-31
# 8 tweets found, 781 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-01%20until%3A2017-04-02include%3Aretweets&src=typd
# 2017-04-01
# 7 tweets found, 789 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-02%20until%3A2017-04-03include%3Aretweets&src=typd
# 2017-04-02
# 3 tweets found, 796 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-03%20until%3A2017-04-04include%3Aretweets&src=typd
# 2017-04-03
# 8 tweets found, 799 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-04%20until%3A2017-04-05include%3Aretweets&src=typd
# 2017-04-04
# 3 tweets found, 807 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-05%20until%3A2017-04-06include%3Aretweets&src=typd
# 2017-04-05
# 1 tweets found, 810 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-06%20until%3A2017-04-07include%3Aretweets&src=typd
# 2017-04-06
# 2 tweets found, 811 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-07%20until%3A2017-04-08include%3Aretweets&src=typd
# 2017-04-07
# 0 tweets found, 813 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-08%20until%3A2017-04-09include%3Aretweets&src=typd
# 2017-04-08
# 5 tweets found, 813 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-09%20until%3A2017-04-10include%3Aretweets&src=typd
# 2017-04-09
# 2 tweets found, 818 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-10%20until%3A2017-04-11include%3Aretweets&src=typd
# 2017-04-10
# 3 tweets found, 820 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-11%20until%3A2017-04-12include%3Aretweets&src=typd
# 2017-04-11
# 4 tweets found, 823 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-12%20until%3A2017-04-13include%3Aretweets&src=typd
# 2017-04-12
# 6 tweets found, 827 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-13%20until%3A2017-04-14include%3Aretweets&src=typd
# 2017-04-13
# 4 tweets found, 833 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-14%20until%3A2017-04-15include%3Aretweets&src=typd
# 2017-04-14
# 1 tweets found, 837 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-15%20until%3A2017-04-16include%3Aretweets&src=typd
# 2017-04-15
# 0 tweets found, 838 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-16%20until%3A2017-04-17include%3Aretweets&src=typd
# 2017-04-16
# 5 tweets found, 838 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-17%20until%3A2017-04-18include%3Aretweets&src=typd
# 2017-04-17
# 7 tweets found, 843 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-18%20until%3A2017-04-19include%3Aretweets&src=typd
# 2017-04-18
# 7 tweets found, 850 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-19%20until%3A2017-04-20include%3Aretweets&src=typd
# 2017-04-19
# 4 tweets found, 857 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-20%20until%3A2017-04-21include%3Aretweets&src=typd
# 2017-04-20
# 4 tweets found, 861 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-21%20until%3A2017-04-22include%3Aretweets&src=typd
# 2017-04-21
# 4 tweets found, 865 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-22%20until%3A2017-04-23include%3Aretweets&src=typd
# 2017-04-22
# 7 tweets found, 869 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-23%20until%3A2017-04-24include%3Aretweets&src=typd
# 2017-04-23
# 7 tweets found, 876 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-24%20until%3A2017-04-25include%3Aretweets&src=typd
# 2017-04-24
# 6 tweets found, 883 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-25%20until%3A2017-04-26include%3Aretweets&src=typd
# 2017-04-25
# 5 tweets found, 889 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-26%20until%3A2017-04-27include%3Aretweets&src=typd
# 2017-04-26
# 9 tweets found, 894 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-27%20until%3A2017-04-28include%3Aretweets&src=typd
# 2017-04-27
# scrolling down to load more tweets
# 12 tweets found, 903 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-28%20until%3A2017-04-29include%3Aretweets&src=typd
# 2017-04-28
# 3 tweets found, 915 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-29%20until%3A2017-04-30include%3Aretweets&src=typd
# 2017-04-29
# 3 tweets found, 918 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-04-30%20until%3A2017-05-01include%3Aretweets&src=typd
# 2017-04-30
# 5 tweets found, 921 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-01%20until%3A2017-05-02include%3Aretweets&src=typd
# 2017-05-01
# 2 tweets found, 926 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-02%20until%3A2017-05-03include%3Aretweets&src=typd
# 2017-05-02
# 4 tweets found, 928 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-03%20until%3A2017-05-04include%3Aretweets&src=typd
# 2017-05-03
# 3 tweets found, 932 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-04%20until%3A2017-05-05include%3Aretweets&src=typd
# 2017-05-04
# 9 tweets found, 935 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-05%20until%3A2017-05-06include%3Aretweets&src=typd
# 2017-05-05
# scrolling down to load more tweets
# 10 tweets found, 944 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-06%20until%3A2017-05-07include%3Aretweets&src=typd
# 2017-05-06
# 1 tweets found, 954 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-07%20until%3A2017-05-08include%3Aretweets&src=typd
# 2017-05-07
# 4 tweets found, 955 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-08%20until%3A2017-05-09include%3Aretweets&src=typd
# 2017-05-08
# 8 tweets found, 959 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-09%20until%3A2017-05-10include%3Aretweets&src=typd
# 2017-05-09
# 2 tweets found, 967 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-10%20until%3A2017-05-11include%3Aretweets&src=typd
# 2017-05-10
# 9 tweets found, 969 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-11%20until%3A2017-05-12include%3Aretweets&src=typd
# 2017-05-11
# 6 tweets found, 978 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-12%20until%3A2017-05-13include%3Aretweets&src=typd
# 2017-05-12
# 9 tweets found, 984 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-13%20until%3A2017-05-14include%3Aretweets&src=typd
# 2017-05-13
# 3 tweets found, 993 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-14%20until%3A2017-05-15include%3Aretweets&src=typd
# 2017-05-14
# 1 tweets found, 996 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-15%20until%3A2017-05-16include%3Aretweets&src=typd
# 2017-05-15
# 1 tweets found, 997 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-16%20until%3A2017-05-17include%3Aretweets&src=typd
# 2017-05-16
# 6 tweets found, 998 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-17%20until%3A2017-05-18include%3Aretweets&src=typd
# 2017-05-17
# 1 tweets found, 1004 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-18%20until%3A2017-05-19include%3Aretweets&src=typd
# 2017-05-18
# 3 tweets found, 1005 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-19%20until%3A2017-05-20include%3Aretweets&src=typd
# 2017-05-19
# 3 tweets found, 1008 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-20%20until%3A2017-05-21include%3Aretweets&src=typd
# 2017-05-20
# 2 tweets found, 1011 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-21%20until%3A2017-05-22include%3Aretweets&src=typd
# 2017-05-21
# 2 tweets found, 1013 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-22%20until%3A2017-05-23include%3Aretweets&src=typd
# 2017-05-22
# 1 tweets found, 1015 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-23%20until%3A2017-05-24include%3Aretweets&src=typd
# 2017-05-23
# 4 tweets found, 1016 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-24%20until%3A2017-05-25include%3Aretweets&src=typd
# 2017-05-24
# 2 tweets found, 1020 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-25%20until%3A2017-05-26include%3Aretweets&src=typd
# 2017-05-25
# 3 tweets found, 1022 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-26%20until%3A2017-05-27include%3Aretweets&src=typd
# 2017-05-26
# 4 tweets found, 1025 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-27%20until%3A2017-05-28include%3Aretweets&src=typd
# 2017-05-27
# 7 tweets found, 1029 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-28%20until%3A2017-05-29include%3Aretweets&src=typd
# 2017-05-28
# 8 tweets found, 1036 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-29%20until%3A2017-05-30include%3Aretweets&src=typd
# 2017-05-29
# 6 tweets found, 1044 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-30%20until%3A2017-05-31include%3Aretweets&src=typd
# 2017-05-30
# 3 tweets found, 1050 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-05-31%20until%3A2017-06-01include%3Aretweets&src=typd
# 2017-05-31
# 8 tweets found, 1053 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-01%20until%3A2017-06-02include%3Aretweets&src=typd
# 2017-06-01
# 5 tweets found, 1061 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-02%20until%3A2017-06-03include%3Aretweets&src=typd
# 2017-06-02
# 2 tweets found, 1066 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-03%20until%3A2017-06-04include%3Aretweets&src=typd
# 2017-06-03
# 3 tweets found, 1068 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-04%20until%3A2017-06-05include%3Aretweets&src=typd
# 2017-06-04
# 3 tweets found, 1071 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-05%20until%3A2017-06-06include%3Aretweets&src=typd
# 2017-06-05
# 8 tweets found, 1074 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-06%20until%3A2017-06-07include%3Aretweets&src=typd
# 2017-06-06
# 8 tweets found, 1082 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-07%20until%3A2017-06-08include%3Aretweets&src=typd
# 2017-06-07
# 5 tweets found, 1090 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-08%20until%3A2017-06-09include%3Aretweets&src=typd
# 2017-06-08
# 0 tweets found, 1095 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-09%20until%3A2017-06-10include%3Aretweets&src=typd
# 2017-06-09
# 6 tweets found, 1095 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-10%20until%3A2017-06-11include%3Aretweets&src=typd
# 2017-06-10
# 2 tweets found, 1101 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-11%20until%3A2017-06-12include%3Aretweets&src=typd
# 2017-06-11
# 4 tweets found, 1103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-12%20until%3A2017-06-13include%3Aretweets&src=typd
# 2017-06-12
# 6 tweets found, 1107 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-13%20until%3A2017-06-14include%3Aretweets&src=typd
# 2017-06-13
# 9 tweets found, 1113 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-14%20until%3A2017-06-15include%3Aretweets&src=typd
# 2017-06-14
# 3 tweets found, 1122 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-15%20until%3A2017-06-16include%3Aretweets&src=typd
# 2017-06-15
# 7 tweets found, 1125 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-16%20until%3A2017-06-17include%3Aretweets&src=typd
# 2017-06-16
# 7 tweets found, 1132 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-17%20until%3A2017-06-18include%3Aretweets&src=typd
# 2017-06-17
# 2 tweets found, 1139 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-18%20until%3A2017-06-19include%3Aretweets&src=typd
# 2017-06-18
# 4 tweets found, 1141 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-19%20until%3A2017-06-20include%3Aretweets&src=typd
# 2017-06-19
# 8 tweets found, 1145 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-20%20until%3A2017-06-21include%3Aretweets&src=typd
# 2017-06-20
# 5 tweets found, 1153 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-21%20until%3A2017-06-22include%3Aretweets&src=typd
# 2017-06-21
# 9 tweets found, 1158 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-22%20until%3A2017-06-23include%3Aretweets&src=typd
# 2017-06-22
# scrolling down to load more tweets
# 13 tweets found, 1167 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-23%20until%3A2017-06-24include%3Aretweets&src=typd
# 2017-06-23
# 5 tweets found, 1180 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-24%20until%3A2017-06-25include%3Aretweets&src=typd
# 2017-06-24
# 6 tweets found, 1185 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-25%20until%3A2017-06-26include%3Aretweets&src=typd
# 2017-06-25
# 1 tweets found, 1191 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-26%20until%3A2017-06-27include%3Aretweets&src=typd
# 2017-06-26
# 7 tweets found, 1192 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-27%20until%3A2017-06-28include%3Aretweets&src=typd
# 2017-06-27
# 7 tweets found, 1199 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-28%20until%3A2017-06-29include%3Aretweets&src=typd
# 2017-06-28
# 8 tweets found, 1206 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-29%20until%3A2017-06-30include%3Aretweets&src=typd
# 2017-06-29
# scrolling down to load more tweets
# 13 tweets found, 1214 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-06-30%20until%3A2017-07-01include%3Aretweets&src=typd
# 2017-06-30
# 7 tweets found, 1227 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-01%20until%3A2017-07-02include%3Aretweets&src=typd
# 2017-07-01
# scrolling down to load more tweets
# 11 tweets found, 1234 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-02%20until%3A2017-07-03include%3Aretweets&src=typd
# 2017-07-02
# 4 tweets found, 1245 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-03%20until%3A2017-07-04include%3Aretweets&src=typd
# 2017-07-03
# 9 tweets found, 1249 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-04%20until%3A2017-07-05include%3Aretweets&src=typd
# 2017-07-04
# 5 tweets found, 1258 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-05%20until%3A2017-07-06include%3Aretweets&src=typd
# 2017-07-05
# 5 tweets found, 1263 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-06%20until%3A2017-07-07include%3Aretweets&src=typd
# 2017-07-06
# 4 tweets found, 1268 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-07%20until%3A2017-07-08include%3Aretweets&src=typd
# 2017-07-07
# 7 tweets found, 1272 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-08%20until%3A2017-07-09include%3Aretweets&src=typd
# 2017-07-08
# 4 tweets found, 1279 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-09%20until%3A2017-07-10include%3Aretweets&src=typd
# 2017-07-09
# scrolling down to load more tweets
# 11 tweets found, 1283 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-10%20until%3A2017-07-11include%3Aretweets&src=typd
# 2017-07-10
# 5 tweets found, 1294 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-11%20until%3A2017-07-12include%3Aretweets&src=typd
# 2017-07-11
# 4 tweets found, 1299 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-12%20until%3A2017-07-13include%3Aretweets&src=typd
# 2017-07-12
# scrolling down to load more tweets
# 12 tweets found, 1303 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2017-07-13%20until%3A2017-07-14include%3Aretweets&src=typd
# 2017-07-13
# 4 tweets found, 1315 total
# ...
# 11 tweets found, 5264 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-01%20until%3A2018-12-02include%3Aretweets&src=typd
# 2018-12-01
# 6 tweets found, 5275 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-02%20until%3A2018-12-03include%3Aretweets&src=typd
# 2018-12-02
# 1 tweets found, 5281 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-03%20until%3A2018-12-04include%3Aretweets&src=typd
# 2018-12-03
# scrolling down to load more tweets
# 12 tweets found, 5282 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-04%20until%3A2018-12-05include%3Aretweets&src=typd
# 2018-12-04
# 9 tweets found, 5294 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-05%20until%3A2018-12-06include%3Aretweets&src=typd
# 2018-12-05
# 9 tweets found, 5303 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-06%20until%3A2018-12-07include%3Aretweets&src=typd
# 2018-12-06
# 4 tweets found, 5312 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-07%20until%3A2018-12-08include%3Aretweets&src=typd
# 2018-12-07
# scrolling down to load more tweets
# scrolling down to load more tweets
# 22 tweets found, 5316 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-08%20until%3A2018-12-09include%3Aretweets&src=typd
# 2018-12-08
# scrolling down to load more tweets
# 12 tweets found, 5338 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-09%20until%3A2018-12-10include%3Aretweets&src=typd
# 2018-12-09
# 3 tweets found, 5350 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-10%20until%3A2018-12-11include%3Aretweets&src=typd
# 2018-12-10
# 3 tweets found, 5353 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-11%20until%3A2018-12-12include%3Aretweets&src=typd
# 2018-12-11
# scrolling down to load more tweets
# 13 tweets found, 5356 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-12%20until%3A2018-12-13include%3Aretweets&src=typd
# 2018-12-12
# 3 tweets found, 5369 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-13%20until%3A2018-12-14include%3Aretweets&src=typd
# 2018-12-13
# scrolling down to load more tweets
# 12 tweets found, 5372 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-14%20until%3A2018-12-15include%3Aretweets&src=typd
# 2018-12-14
# 6 tweets found, 5384 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-15%20until%3A2018-12-16include%3Aretweets&src=typd
# 2018-12-15
# 8 tweets found, 5390 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-16%20until%3A2018-12-17include%3Aretweets&src=typd
# 2018-12-16
# scrolling down to load more tweets
# 10 tweets found, 5398 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-17%20until%3A2018-12-18include%3Aretweets&src=typd
# 2018-12-17
# 4 tweets found, 5408 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-18%20until%3A2018-12-19include%3Aretweets&src=typd
# 2018-12-18
# 9 tweets found, 5412 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-19%20until%3A2018-12-20include%3Aretweets&src=typd
# 2018-12-19
# scrolling down to load more tweets
# 12 tweets found, 5421 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-20%20until%3A2018-12-21include%3Aretweets&src=typd
# 2018-12-20
# scrolling down to load more tweets
# 15 tweets found, 5433 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-21%20until%3A2018-12-22include%3Aretweets&src=typd
# 2018-12-21
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 5448 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-22%20until%3A2018-12-23include%3Aretweets&src=typd
# 2018-12-22
# 9 tweets found, 5468 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-23%20until%3A2018-12-24include%3Aretweets&src=typd
# 2018-12-23
# scrolling down to load more tweets
# 11 tweets found, 5477 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-24%20until%3A2018-12-25include%3Aretweets&src=typd
# 2018-12-24
# scrolling down to load more tweets
# 17 tweets found, 5488 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-25%20until%3A2018-12-26include%3Aretweets&src=typd
# 2018-12-25
# 2 tweets found, 5505 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-26%20until%3A2018-12-27include%3Aretweets&src=typd
# 2018-12-26
# 1 tweets found, 5507 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-27%20until%3A2018-12-28include%3Aretweets&src=typd
# 2018-12-27
# scrolling down to load more tweets
# 10 tweets found, 5508 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-28%20until%3A2018-12-29include%3Aretweets&src=typd
# 2018-12-28
# 5 tweets found, 5518 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-29%20until%3A2018-12-30include%3Aretweets&src=typd
# 2018-12-29
# 7 tweets found, 5523 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-30%20until%3A2018-12-31include%3Aretweets&src=typd
# 2018-12-30
# 5 tweets found, 5530 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2018-12-31%20until%3A2019-01-01include%3Aretweets&src=typd
# 2018-12-31
# scrolling down to load more tweets
# 11 tweets found, 5535 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-01%20until%3A2019-01-02include%3Aretweets&src=typd
# 2019-01-01
# scrolling down to load more tweets
# 15 tweets found, 5546 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-02%20until%3A2019-01-03include%3Aretweets&src=typd
# 2019-01-02
# 3 tweets found, 5561 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-03%20until%3A2019-01-04include%3Aretweets&src=typd
# 2019-01-03
# 9 tweets found, 5564 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-04%20until%3A2019-01-05include%3Aretweets&src=typd
# 2019-01-04
# 7 tweets found, 5573 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-05%20until%3A2019-01-06include%3Aretweets&src=typd
# 2019-01-05
# scrolling down to load more tweets
# 12 tweets found, 5580 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-06%20until%3A2019-01-07include%3Aretweets&src=typd
# 2019-01-06
# scrolling down to load more tweets
# 10 tweets found, 5592 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-07%20until%3A2019-01-08include%3Aretweets&src=typd
# 2019-01-07
# 6 tweets found, 5602 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-08%20until%3A2019-01-09include%3Aretweets&src=typd
# 2019-01-08
# 5 tweets found, 5608 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-09%20until%3A2019-01-10include%3Aretweets&src=typd
# 2019-01-09
# 6 tweets found, 5613 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-10%20until%3A2019-01-11include%3Aretweets&src=typd
# 2019-01-10
# scrolling down to load more tweets
# 10 tweets found, 5619 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-11%20until%3A2019-01-12include%3Aretweets&src=typd
# 2019-01-11
# scrolling down to load more tweets
# 12 tweets found, 5629 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-12%20until%3A2019-01-13include%3Aretweets&src=typd
# 2019-01-12
# scrolling down to load more tweets
# 13 tweets found, 5641 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-13%20until%3A2019-01-14include%3Aretweets&src=typd
# 2019-01-13
# 9 tweets found, 5654 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-14%20until%3A2019-01-15include%3Aretweets&src=typd
# 2019-01-14
# scrolling down to load more tweets
# 15 tweets found, 5663 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-15%20until%3A2019-01-16include%3Aretweets&src=typd
# 2019-01-15
# 8 tweets found, 5678 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-16%20until%3A2019-01-17include%3Aretweets&src=typd
# 2019-01-16
# 2 tweets found, 5686 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-17%20until%3A2019-01-18include%3Aretweets&src=typd
# 2019-01-17
# 2 tweets found, 5688 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-18%20until%3A2019-01-19include%3Aretweets&src=typd
# 2019-01-18
# scrolling down to load more tweets
# 13 tweets found, 5690 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-19%20until%3A2019-01-20include%3Aretweets&src=typd
# 2019-01-19
# scrolling down to load more tweets
# 11 tweets found, 5703 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-20%20until%3A2019-01-21include%3Aretweets&src=typd
# 2019-01-20
# scrolling down to load more tweets
# 11 tweets found, 5714 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-21%20until%3A2019-01-22include%3Aretweets&src=typd
# 2019-01-21
# scrolling down to load more tweets
# 15 tweets found, 5725 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-22%20until%3A2019-01-23include%3Aretweets&src=typd
# 2019-01-22
# scrolling down to load more tweets
# 12 tweets found, 5740 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-23%20until%3A2019-01-24include%3Aretweets&src=typd
# 2019-01-23
# 8 tweets found, 5752 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-24%20until%3A2019-01-25include%3Aretweets&src=typd
# 2019-01-24
# scrolling down to load more tweets
# 10 tweets found, 5760 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-25%20until%3A2019-01-26include%3Aretweets&src=typd
# 2019-01-25
# 4 tweets found, 5770 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-26%20until%3A2019-01-27include%3Aretweets&src=typd
# 2019-01-26
# scrolling down to load more tweets
# 10 tweets found, 5774 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-27%20until%3A2019-01-28include%3Aretweets&src=typd
# 2019-01-27
# 9 tweets found, 5784 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-28%20until%3A2019-01-29include%3Aretweets&src=typd
# 2019-01-28
# 6 tweets found, 5793 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-29%20until%3A2019-01-30include%3Aretweets&src=typd
# 2019-01-29
# 3 tweets found, 5799 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-30%20until%3A2019-01-31include%3Aretweets&src=typd
# 2019-01-30
# scrolling down to load more tweets
# 12 tweets found, 5802 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-01-31%20until%3A2019-02-01include%3Aretweets&src=typd
# 2019-01-31
# scrolling down to load more tweets
# 16 tweets found, 5814 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-01%20until%3A2019-02-02include%3Aretweets&src=typd
# 2019-02-01
# scrolling down to load more tweets
# 11 tweets found, 5830 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-02%20until%3A2019-02-03include%3Aretweets&src=typd
# 2019-02-02
# 1 tweets found, 5841 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-03%20until%3A2019-02-04include%3Aretweets&src=typd
# 2019-02-03
# 5 tweets found, 5842 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-04%20until%3A2019-02-05include%3Aretweets&src=typd
# 2019-02-04
# 1 tweets found, 5847 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-05%20until%3A2019-02-06include%3Aretweets&src=typd
# 2019-02-05
# 4 tweets found, 5848 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-06%20until%3A2019-02-07include%3Aretweets&src=typd
# 2019-02-06
# 2 tweets found, 5852 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-07%20until%3A2019-02-08include%3Aretweets&src=typd
# 2019-02-07
# 6 tweets found, 5854 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-08%20until%3A2019-02-09include%3Aretweets&src=typd
# 2019-02-08
# scrolling down to load more tweets
# 10 tweets found, 5860 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-09%20until%3A2019-02-10include%3Aretweets&src=typd
# 2019-02-09
# 8 tweets found, 5870 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-10%20until%3A2019-02-11include%3Aretweets&src=typd
# 2019-02-10
# scrolling down to load more tweets
# 11 tweets found, 5878 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-11%20until%3A2019-02-12include%3Aretweets&src=typd
# 2019-02-11
# 9 tweets found, 5889 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-12%20until%3A2019-02-13include%3Aretweets&src=typd
# 2019-02-12
# 5 tweets found, 5898 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-13%20until%3A2019-02-14include%3Aretweets&src=typd
# 2019-02-13
# 4 tweets found, 5903 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-14%20until%3A2019-02-15include%3Aretweets&src=typd
# 2019-02-14
# 7 tweets found, 5907 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-15%20until%3A2019-02-16include%3Aretweets&src=typd
# 2019-02-15
# 3 tweets found, 5914 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-16%20until%3A2019-02-17include%3Aretweets&src=typd
# 2019-02-16
# 2 tweets found, 5917 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-02-17%20until%3A2019-02-18include%3Aretweets&src=typd
# 2019-02-17
# scrolling down to load more tweets
# 11 tweets found, 5919 total
# tweets found on this scrape:  5930
# total tweet count:  5930
# all done here

# %%
# Mass Data 
import tweepy
import json
import math
import glob
import csv
import zipfile
import zlib
from tweepy import TweepError
from time import sleep
import unicodedata
user = 'realdonaldtrump'
# Consumer keys and access tokens, used for OAuth
consumer_key = 'MKFuTmc28rZ8UARafp6Xc9R6f'
consumer_secret = 'uuw9QolA6jEfDNVCi0YNLBYOGyk44FIqQOjPPHLH60JAUMhl8o'
#Access
access_token = '797075677946277888-CBRjWMulthQ1RD94GJ5ZojA4sFPzixj'
access_token_secret = 'fpjUviOHzgGxzWiOYLrrSQ6SJb52qhRd6QESbCs7VzirK'

# OAuth
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
api = tweepy.API(auth) 

user = user.lower()
output_file = '{}.json'.format(user)
output_file_short = '{}_short.json'.format(user)
compression = zipfile.ZIP_DEFLATED

with open('all_ids.json') as f:
    ids = json.load(f)

print('total ids: {}'.format(len(ids)))

all_data = []
start = 0
end = 100
limit = len(ids)
i = math.ceil(limit / 100)

for go in range(i):
    print('currently getting {} - {}'.format(start, end))
    sleep(6)  # needed to prevent hitting API rate limit
    id_batch = ids[start:end]
    start += 100
    end += 100
    tweets = api.statuses_lookup(id_batch)
    for tweet in tweets:
        all_data.append(dict(tweet._json))

print('metadata collection complete')
print('creating master json file')
with open(output_file, 'w') as outfile:
    json.dump(all_data, outfile)

print('creating ziped master json file')
zf = zipfile.ZipFile('{}.zip'.format(user), mode='w')
zf.write(output_file, compress_type=compression)
zf.close()

results = []

def is_retweet(entry):
    return 'retweeted_status' in entry.keys()

def get_source(entry):
    if '<' in entry["source"]:
        return entry["source"].split('>')[1].split('<')[0]
    else:
        return entry["source"]

with open(output_file) as json_data:
    data = json.load(json_data)
    for entry in data:
        t = {
            "created_at": entry["created_at"],
            "text": entry["text"],
            "in_reply_to_screen_name": entry["in_reply_to_screen_name"],
            "retweet_count": entry["retweet_count"],
            "favorite_count": entry["favorite_count"],
            "source": get_source(entry),
            "id_str": entry["id_str"],
            "is_retweet": is_retweet(entry)
        }
        results.append(t)

print('creating minimized json master file')
with open(output_file_short, 'w') as outfile:
    json.dump(results, outfile)
# Out:
# total ids: 5930
# currently getting 0 - 100
# currently getting 100 - 200
# currently getting 200 - 300
# currently getting 300 - 400
# currently getting 400 - 500
# currently getting 500 - 600
# currently getting 600 - 700
# currently getting 700 - 800
# currently getting 800 - 900
# currently getting 900 - 1000
# currently getting 1000 - 1100
# currently getting 1100 - 1200
# currently getting 1200 - 1300
# currently getting 1300 - 1400
# currently getting 1400 - 1500
# currently getting 1500 - 1600
# currently getting 1600 - 1700
# currently getting 1700 - 1800
# currently getting 1800 - 1900
# currently getting 1900 - 2000
# currently getting 2000 - 2100
# currently getting 2100 - 2200
# currently getting 2200 - 2300
# currently getting 2300 - 2400
# currently getting 2400 - 2500
# currently getting 2500 - 2600
# currently getting 2600 - 2700
# currently getting 2700 - 2800
# currently getting 2800 - 2900
# currently getting 2900 - 3000
# currently getting 3000 - 3100
# currently getting 3100 - 3200
# currently getting 3200 - 3300
# currently getting 3300 - 3400
# currently getting 3400 - 3500
# currently getting 3500 - 3600
# currently getting 3600 - 3700
# currently getting 3700 - 3800
# currently getting 3800 - 3900
# currently getting 3900 - 4000
# currently getting 4000 - 4100
# currently getting 4100 - 4200
# currently getting 4200 - 4300
# currently getting 4300 - 4400
# currently getting 4400 - 4500
# currently getting 4500 - 4600
# currently getting 4600 - 4700
# currently getting 4700 - 4800
# currently getting 4800 - 4900
# currently getting 4900 - 5000
# currently getting 5000 - 5100
# currently getting 5100 - 5200
# currently getting 5200 - 5300
# currently getting 5300 - 5400
# currently getting 5400 - 5500
# currently getting 5500 - 5600
# currently getting 5600 - 5700
# currently getting 5700 - 5800
# currently getting 5800 - 5900
# currently getting 5900 - 6000
# metadata collection complete
# creating master json file
# creating ziped master json file
# creating minimized json master file

# %%
# Open File
with open(r'C:\Users\sarin_000\Desktop\ds_projects\ga_repo\realdonaldtrump_short.json') as f:
    jsondata = json.load(f)

normalized_json = pd.io.json.json_normalize(jsondata)

tweets = pd.DataFrame(normalized_json)
#Covert Pandas to Datetime
tweets['created_at'] = pd.to_datetime(tweets['created_at'])
tweets.text.fillna(tweets.text, inplace=True)

# %%
#Sorty by time
tweets.sort_values(['created_at'], ascending=True,inplace=True)
tweets.head(2)
# Out:
#               created_at  favorite_count              id_str  \
# 2913 2016-11-01 10:31:46           48997  793400131525677056
# 3321 2016-11-01 11:55:47           34432  793421274043285504
#
#      in_reply_to_screen_name  is_retweet  retweet_count               source  \
# 2913                    None       False          19118  Twitter for Android
# 3321                    None       False          14704  Twitter for Android
#
#                                                    text
# 2913  Look at the way Crooked Hillary is handling th...
# 3321  Wow, now leading in @ABC /@washingtonpost Poll...

# %%
# Drop unnecessary columns
tweets.drop(['id_str','in_reply_to_screen_name','is_retweet'], axis=1, inplace=True)
tweets.head(3)
# Out:
#               created_at  favorite_count  retweet_count               source  \
# 2913 2016-11-01 10:31:46           48997          19118  Twitter for Android
# 3321 2016-11-01 11:55:47           34432          14704  Twitter for Android
# 1304 2016-11-01 12:01:11           52775          21172  Twitter for Android
#
#                                                    text
# 2913  Look at the way Crooked Hillary is handling th...
# 3321  Wow, now leading in @ABC /@washingtonpost Poll...
# 1304  Crooked Hillary should not be allowed to run f...

# %% [markdown]
# # 2. Descriptive Analysis

# %% [markdown]
# Total Tweets from Nov.1. 2016 to Feb. 17 2019

# %%
tweets.shape
# Out:
# (5930, 5)

# %%
tweets.columns
# Out:
# Index(['created_at', 'favorite_count', 'retweet_count', 'source', 'text'], dtype='object')

# %%
tweets.isnull().sum()
# Out:
# created_at        0
# favorite_count    0
# retweet_count     0
# source            0
# text              0
# dtype: int64

# %%
# Total tweets for the priod 
print ('Total tweets start from Nov. 1, 2016 to Feb. 17,2019 : ',len(tweets.index),'\n')
# Out:
# Total tweets start from Nov. 1, 2016 to Feb. 17,2019 :  5930

# %%
# Retweets
tweet_retweets = tweets.sort_values(by='retweet_count', ascending=False)
tweet_retweets= tweet_retweets.reset_index(drop=True)
print ('Average retweets:', round(tweet_retweets['retweet_count'].mean(),2), '\n')
print ('Top 5 Retweets:')
for i in range(5): #iloc to prinit row until i
    print (tweet_retweets['text'].iloc[i], '-', tweet_retweets['retweet_count'].iloc[i])
# Out:
# Average retweets: 19728.48
#
# Top 5 Retweets:
# #FraudNewsCNN #FNN https://t.co/WYUnHjjUjg - 330186
# TODAY WE MAKE AMERICA GREAT AGAIN! - 312109
# Why would Kim Jong-un insult me by calling me "old," when I would NEVER call him "short and fat?" Oh well, I try so… https://t.co/PmsWNkH4r4 - 246419
# Such a beautiful and important evening! The forgotten man and woman will never be forgotten again. We will all come together as never before - 197935
# North Korean Leader Kim Jong Un just stated that the “Nuclear Button is on his desk at all times.” Will someone fro… https://t.co/EvTgZxiji0 - 174606

# %%
# Likes
tweet_likes = tweets.sort_values(by='favorite_count', ascending=False)
tweet_likes = tweet_likes.reset_index(drop=True)
print ('Average likes:', round(tweet_likes['favorite_count'].mean(),2), '\n')
print ('Top 5 Liked:')
for i in range(5):
    print (tweet_likes['text'].iloc[i], '-', tweet_likes['favorite_count'].iloc[i])
# Out:
# Average likes: 84952.47
#
# Top 5 Liked:
# Such a beautiful and important evening! The forgotten man and woman will never be forgotten again. We will all come together as never before - 584620
# Why would Kim Jong-un insult me by calling me "old," when I would NEVER call him "short and fat?" Oh well, I try so… https://t.co/PmsWNkH4r4 - 583598
# #FraudNewsCNN #FNN https://t.co/WYUnHjjUjg - 552026
# TODAY WE MAKE AMERICA GREAT AGAIN! - 535142
# Merry Christmas! - 501996

# %%
# Find mostly used words
from collections import Counter

import string

from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS


custom_stop_words = list(ENGLISH_STOP_WORDS)

# RegEx for stopwords
# \b backslash B word boundary(white space)
#?:It's called a 'non-capturing group', which means the regex would not make a group by the match inside the parenteses like it would otherwise do (normally, a parenthesis creates a group).
# format() will replace {}. {} for expandsion
# | means either or
RE_stopwords = r'\b(?:{})\b'.format('|'.join(custom_stop_words))

words = (tweets.text
           .str.lower()
           .replace([r'\|',RE_stopwords ], [' ', ''], regex=True)
           .str.cat(sep=' ') # Concatenate  strings in a series/index with given seperater
           .split()
)
words
# Out:
# ['look',
#  'way',
#  'crooked',
#  'hillary',
#  'handling',
#  'e-mail',
#  'case',
#  'total',
#  'mess',
#  '.',
#  'unfit',
#  'president.',
#  'bad',
#  'judgement!',
#  'wow,',
#  'leading',
#  '@abc',
#  '/@washingtonpost',
#  'poll',
#  '46',
#  '45.',
#  'gone',
#  '12',
#  'points',
#  'weeks,',
#  'crooked',
#  'hillary',
#  'blow-!',
#  'crooked',
#  'hillary',
#  'allowed',
#  'run',
#  'president.',
#  'deleted',
#  '33,000',
#  'e-mails',
#  'getting',
#  'subpoena',
#  'u.s.',
#  'congress.',
#  'rigged!',
#  'join',
#  'tomorrow',
#  'florida!',
#  'miami•12pm',
#  'https://t./a3x71q6sg2',
#  'orlando•4pm',
#  'https://t./6bqtvoty5c',
#  'pensacola•7p…',
#  'https://t./knzraeulzo',
#  'terrible',
#  'crooked',
#  "didn't",
#  'report',
#  'got',
#  'debate',
#  'questions',
#  'donna',
#  'brazile,',
#  'page',
#  'news!',
#  '#icymi:',
#  'governor',
#  '@mike_pence',
#  'valley',
#  'forge,',
#  'pennsylvania',
#  'today.',
#  'watch',
#  ':…',
#  'https://t./6gwgmcv23z',
#  '.@darrellissa',
#  'good',
#  'man.',
#  'help',
#  'win',
#  'congressional',
#  'seat',
#  'california.',
#  "'kept",
#  "jail':",
#  'doj',
#  'official',
#  'involved',
#  'clinton',
#  'probe',
#  'represented',
#  'campaign',
#  'chairman:',
#  'https://t./quzn97ceoq',
#  'trump',
#  'promises',
#  'special',
#  'session',
#  'repeal',
#  'obamacare:',
#  'https://t./wtcd108yrv',
#  'hillary',
#  'advisers',
#  'wanted',
#  'avoid',
#  'supporting',
#  'israel',
#  'talking',
#  'democrats:',
#  'https://t./y7m8ivu173',
#  'mika',
#  'brzezinski:',
#  'dem',
#  'criticism',
#  'comey',
#  'reinforcing',
#  'idea',
#  '‘’s',
#  "'",
#  'https://t./evbp0xespn',
#  'https://t./qidbidpat8',
#  "'podesta",
#  'urged',
#  'clinton',
#  'team',
#  'hand',
#  'emails',
#  'use',
#  'private',
#  'server',
#  "emerged'",
#  'https://t./nyvvmoa8wl',
#  'wikileaks',
#  'emails',
#  'reveal',
#  'podesta',
#  'urging',
#  'clinton',
#  'camp',
#  "'dump'",
#  'emails.',
#  'time',
#  '#draintheswamp!',
#  'https://t./p3ajiacixk',
#  'thank',
#  'incredible',
#  'support',
#  'wisconsin',
#  'governor',
#  '@scottwalker!',
#  'time',
#  '#draintheswamp',
#  '&amp;',
#  '#maga!…',
#  'https://t./gkbkkmtudn',
#  'join',
#  'florida',
#  'tomorrow!',
#  'miami•12pm',
#  'https://t./a3x71q6sg2',
#  'orlando•4pm',
#  'https://t./6bqtvoty5c',
#  'pensacola•7p…',
#  'https://t./kequujeo1b',
#  'change',
#  'vote',
#  'states.',
#  ',',
#  'hillary',
#  'big',
#  'mistake,',
#  'change',
#  'vote',
#  'make',
#  'america',
#  'great',
#  '!',
#  'going',
#  'repeal',
#  'replace',
#  'obamacare.',
#  'expensive',
#  'better',
#  'healthcare.',
#  'hillary,',
#  'costs',
#  'triple!',
#  'crooked',
#  'hillary',
#  'clinton',
#  'deleted',
#  '33,000',
#  'e-mails',
#  'subpoenaed',
#  'united',
#  'states',
#  'congress.',
#  'guilty',
#  '-',
#  'run.',
#  'rigged',
#  '!',
#  '"@ravenrantz:',
#  "#billygraham's",
#  'grand',
#  'daughter',
#  '#supportstrump',
#  'https://t./skz1sphzdz"',
#  'nice,',
#  'thank',
#  'cissy',
#  'graham',
#  'lynch!!!!',
#  '"@pynance:',
#  'evangelical',
#  'women',
#  'live',
#  '#trumptower',
#  '@pdpryor1',
#  '@cissieglynch',
#  '@saysgabrielle',
#  'https://t./k5kgxpr2wa"',
#  'praying',
#  'families',
#  'iowa',
#  'police',
#  'ambushed',
#  'morning.',
#  'attack',
#  'safe',
#  'attack',
#  '.',
#  'thank',
#  'miami!',
#  '6',
#  'days,',
#  'going',
#  'win',
#  'great',
#  'state',
#  'florida',
#  '-',
#  'going',
#  'win',
#  'white…',
#  'https://t./mkypop0med',
#  '"',
#  'pays',
#  'friends',
#  'high',
#  'places-',
#  'like',
#  'justice',
#  'department.',
#  'clearly',
#  'clintons',
#  '."',
#  '#draintheswamp!',
#  'https://t./kzxb4b156m',
#  'clinton',
#  'camp',
#  'fumed',
#  'surrogate',
#  'told',
#  'supporters',
#  'clinton',
#  'planned',
#  'betray',
#  'labor',
#  'tpp',
#  'post-election:',
#  'https://t./zzjbgdzp7e',
#  'decades',
#  'lies',
#  'scandal,',
#  'crooked',
#  "hillary's",
#  'corruption',
#  'closing',
#  '.',
#  '#draintheswamp!',
#  'https://t./yivcacmkkq',
#  'thank',
#  'orlando,',
#  'florida!',
#  'just',
#  'days',
#  'away',
#  'delivering',
#  'justice',
#  'forgotten',
#  'man,',
#  'woman',
#  'ch…',
#  'https://t./lpxbqz5axt',
#  '#makeamericagreatagain',
#  '#6days',
#  'https://t./ehtgiepfsm',
#  'thank',
#  'arlene!',
#  'make',
#  'america',
#  'safe',
#  'great',
#  '!',
#  '#imwithyou',
#  '#draintheswamp',
#  'https://t./tsi0yp2ll9',
#  'wife,',
#  'melania,',
#  'speaking',
#  'pennsylvania',
#  'afternoon.',
#  'exciting,',
#  'big',
#  'crowds!',
#  'watching',
#  'north',
#  'carolina.',
#  'obamacare',
#  'total',
#  'disaster.',
#  'hillary',
#  'clinton',
#  'wants',
#  'save',
#  'making',
#  'expensive.',
#  "doesn't",
#  'work,',
#  'repeal',
#  'replace!',
#  'looking',
#  'air',
#  'force',
#  '@',
#  'mia.',
#  'campaigning',
#  'instead',
#  'creating',
#  'jobs',
#  '&amp;',
#  'fixing',
#  'obamacare?',
#  'work',
#  'american',
#  'people!',
#  'watching',
#  'beautiful',
#  'wife,',
#  'melania,',
#  'speak',
#  'love',
#  'country',
#  'family.',
#  'make',
#  'proud.…',
#  'https://t./dikmsntlc2',
#  'thank',
#  'concord,',
#  'north',
#  'carolina!',
#  'win',
#  'november',
#  '8th,',
#  'going',
#  'washington,',
#  'd.c.',
#  'going',
#  't…',
#  'https://t./7j4mbn1waf',
#  '#crookedhillary',
#  'unfit',
#  'serve.',
#  'https://t./bsugvinnf1',
#  'join',
#  'wilmington,',
#  'ohio',
#  'tomorrow',
#  '4:00pm!',
#  'time',
#  '#draintheswamp!',
#  'tickets:',
#  'https://t./eclecm3nmw',
#  'https://t./sb5irrxjxj',
#  'challenge',
#  'great,',
#  'dream',
#  'outside',
#  'reach!',
#  'thank',
#  'selma,',
#  'north',
#  'carolina!',
#  '#icymi,',
#  'watch',
#  '…',
#  'https://t./8uirhgyrsl',
#  'join',
#  'today',
#  'wilmington,',
#  'ohio',
#  '4pm:',
#  'https://t./eclecmkylw',
#  'tomorrow-',
#  'tampa,',
#  'florida',
#  '10am:',
#  'https://t./n9380pvmum',
#  '"',
#  'clinton',
#  'campaign',
#  'obama',
#  'justice"',
#  '#draintheswamp',
#  'https://t./lzkvfc071z',
#  'clinton',
#  'aides:',
#  '‘definitely’',
#  'releasing',
#  'hrc',
#  'emails:',
#  'https://t./gy5pgkadow',
#  'thank',
#  'nh!',
#  'end',
#  'illegal',
#  'immigration,',
#  'stop',
#  'drugs,',
#  'deport',
#  'criminal',
#  'aliens&amp;save',
#  'american',
#  'lives!',
#  'watc…',
#  'https://t./uxcazvkb32',
#  "'ice",
#  'officers',
#  'warn',
#  'hillary',
#  'immigration',
#  'plan',
#  'unleash',
#  'gangs,',
#  'cartels',
#  '&amp;',
#  'drug',
#  'violence',
#  "nationwide'…",
#  'https://t./09asrbwqrv',
#  'obama',
#  'worked',
#  'hard',
#  'straightening',
#  'country',
#  'trying',
#  'protect',
#  'elect',
#  'hillary,',
#  'better',
#  '!',
#  'join',
#  'live',
#  'wilmington,',
#  'ohio!',
#  'https://t./nq2p4eullu',
#  'thank',
#  'ohio!',
#  'vote',
#  'replace',
#  'obamacare',
#  'save',
#  'healthcare',
#  'family',
#  'united',
#  'states!',
#  'watch:…',
#  'https://t./7ch8zngdoa',
#  'thing',
#  'stop',
#  'corrupt',
#  'machine',
#  '.',
#  'force',
#  'strong',
#  'save',
#  'country',
#  '.…',
#  'https://t./7dcshokuzc',
#  'join',
#  'live',
#  'hershey,',
#  'pennsylvania!',
#  '#makeamericagreatagain',
#  'live:',
#  'https://t./xej6szpb12',
#  'https://t./jwfgi1vlww',
#  'join',
#  'denver,',
#  'colorado',
#  'tomorrow',
#  '9:30pm!',
#  'tickets:',
#  'https://t./ljygik7mri',
#  'thank',
#  'hershey,',
#  'pennsylvania.',
#  '&amp;',
#  'vote',
#  'november',
#  '8th',
#  '&amp;',
#  '#maga!',
#  '#rallyforriley',
#  '#icymi,',
#  'watch',
#  '…',
#  'https://t./mawukvbtr8',
#  'make',
#  'america',
#  'great',
#  '!',
#  'join',
#  'denver,',
#  'colorado',
#  'tonight',
#  '9:30pm:',
#  'https://t./ljygik7mri',
#  'new-',
#  'scranton,',
#  'pennsylvania',
#  'monday',
#  '@',
#  '5:30pm:',
#  'https://t./bcerctspdf',
#  'thank',
#  'incredible',
#  'support',
#  'morning',
#  'tampa,',
#  'florida!',
#  '#icymi-',
#  'watch',
#  ':',
#  'https://t./q43khf7moe',
#  'https://t./1gscfnav4l',
#  'thank',
#  'wilmington,',
#  'north',
#  'carolina.',
#  '3',
#  'days',
#  'away',
#  'change',
#  "'ve",
#  'waiting',
#  'entire',
#  'life!…',
#  'https://t./6zjzrbflst',
#  'watch',
#  'coach',
#  'mike',
#  'ditka-',
#  'great',
#  'guy',
#  'supporter',
#  'tonight',
#  '8pme',
#  '#wattersworld',
#  '@jessebwatters',
#  '@foxnews.',
#  '‘',
#  'act',
#  'immediately’:',
#  'clinton',
#  'charity',
#  'lawyer',
#  'told',
#  'execs',
#  'breaking',
#  'law',
#  'https://t./hsi4qhqtv1',
#  'clinton',
#  'aides',
#  'bemoan',
#  'campaign',
#  '‘',
#  'tactics,’',
#  'vision:',
#  'https://t./mhyvqtiq78',
#  '#draintheswamp!',
#  'https://t./z68vgp9bvf',
#  'join',
#  'tomorrow!',
#  'minnesota',
#  '•',
#  '2pm',
#  'https://t./wcglh4prs7',
#  'michigan',
#  '•',
#  '6pm',
#  'https://t./9bqgvknnrt',
#  'virginia',
#  '•',
#  '9:30p…',
#  'https://t./a1ovhcrt6t',
#  'join',
#  'live',
#  'reno,',
#  'nevada!',
#  'https://t./t4bf1hrxaa',
#  'https://t./epqrxha1cm',
#  'thank',
#  'reno,',
#  'nevada.',
#  'stop',
#  'quest',
#  'make',
#  'america',
#  'safe',
#  'great',
#  '!',
#  '#americafirst…',
#  'https://t./a4eehocbgs',
#  'great',
#  'night',
#  'denver,',
#  'colorado-',
#  'thank',
#  '!',
#  ',',
#  'make',
#  'america',
#  'great',
#  '!',
#  '#icymi',
#  'watch',
#  'rally',
#  ':…',
#  'https://t./lbvnho6t2k',
#  'van',
#  'jones:',
#  '‘',
#  'crack',
#  'blue',
#  'wall’',
#  '—',
#  'trade:',
#  'https://t./bvef9cc7o7',
#  'thank',
#  'iowa',
#  '-',
#  '&amp;',
#  '#votetrumppence16!',
#  'https://t./hfihperfgz',
#  'https://t./qsukelqmkb',
#  'monday',
#  '-',
#  '11/7/2016',
#  'scranton,',
#  'pennsylvania',
#  '5:30pm.',
#  'https://t./bcerctspdf',
#  'grand',
#  'rapids,',
#  'michigan',
#  '11pm.…',
#  'https://t./pgfmlp0173',
#  'thank',
#  'minnesota!',
#  'time',
#  '#draintheswamp',
#  '&amp;',
#  '#maga!',
#  '#icymi-',
#  'watch:',
#  'https://t./fvthc7yil6',
#  'https://t./e8saxijrxj',
#  'american',
#  'comeback',
#  'story',
#  'begins',
#  '11/8/16.',
#  ',',
#  'make',
#  'america',
#  'safe',
#  '&amp;',
#  'great',
#  '!',
#  'watch:…',
#  'https://t./ek8cn3cgtr',
#  'thank',
#  'michigan!',
#  'movement',
#  'seen',
#  '-',
#  "'s",
#  'chance',
#  '#draintheswamp!',
#  'watch…',
#  'https://t./csdgkcfyrl',
#  'thank',
#  'pennsylvania-',
#  'forever',
#  'grateful',
#  'amazing',
#  'support.',
#  'lets',
#  'make',
#  'america',
#  'great',
#  '!',
#  '#maga…',
#  'https://t./qbcjzazw6z',
#  'thank',
#  'support',
#  'virginia!',
#  'day',
#  '-',
#  '#votetrumppence16!',
#  '#icymi:',
#  'https://t./nid8qcftwy',
#  'https://t./wosecjm8sm',
#  'starting',
#  'tomorrow',
#  "'s",
#  'going',
#  '#americafirst!',
#  'thank',
#  'great',
#  'morning',
#  'sarasota,',
#  'florida!',
#  'watch',
#  ':…',
#  'https://t./ig62kjkkvl',
#  'just',
#  'landed',
#  'north',
#  'carolina-',
#  'heading',
#  'j.s.',
#  'dorton',
#  'arena.',
#  'soon!',
#  'lets',
#  '#makeamericagreatagain!',
#  'https://t./euo0kewx1y',
#  'way!',
#  'https://t./6l2ild6r8h',
#  'love',
#  'north',
#  'carolina-',
#  'thank',
#  'amazing',
#  'support!',
#  'https://t./hfihperfgz',
#  'tomorrow!',
#  'watch:…',
#  'https://t./jzzfquznyh',
#  "'",
#  "trump'",
#  'https://t./rpwiyb7aov',
#  "'",
#  'like',
#  'trump',
#  '...',
#  'need',
#  'vote',
#  "'",
#  'https://t./6rvuduehzq',
#  "'america",
#  'decide',
#  'failed',
#  'policies',
#  'fresh',
#  'perspective,',
#  'corrupt',
#  "outsider'",
#  'https://t./ll8qiw9sqw',
#  'hey',
#  'missouri',
#  "let's",
#  'defeat',
#  'crooked',
#  'hillary',
#  '&amp;',
#  '@koster4missouri!',
#  'koster',
#  'supports',
#  'obamacare',
#  '&amp;',
#  'amnesty!',
#  'vote',
#  'outsider',
#  'navy',
#  'seal',
#  '@ericgreitens!',
#  'live',
#  '#periscope:',
#  'join',
#  'minutes',
#  'pennsylvania.',
#  '&amp;',
#  'vote',
#  'tomorrow.',
#  'lets',
#  '#maga!!',
#  'https://t./ej0lmmk3yu',
#  'thank',
#  'pennsylvania!',
#  'going',
#  'new',
#  'hampshire',
#  'michigan.',
#  'watch',
#  'pa',
#  'rally',
#  ':',
#  'https://t./d29dlingst…',
#  'https://t./zch9crfikm',
#  'today',
#  'florida,',
#  'pledged',
#  'stand',
#  'people',
#  'cuba',
#  'venezuela',
#  'fight',
#  'oppression-',
#  'cont:',
#  'https://t./8eelqk2wuw',
#  'big',
#  'news',
#  'share',
#  'new',
#  'hampshire',
#  'tonight!',
#  'polls',
#  'looking',
#  'great!',
#  'soon.',
#  'unbelievable',
#  'evening',
#  'new',
#  'hampshire',
#  '-',
#  'thank',
#  '!',
#  'flying',
#  'grand',
#  'rapids,',
#  'michigan',
#  '.',
#  'watch',
#  'nh',
#  'rally',
#  ':…',
#  'https://t./hp88anrfgk',
#  'today',
#  'going',
#  'win',
#  'great',
#  'state',
#  'michigan',
#  'going',
#  'win',
#  'white',
#  'house!',
#  'thank',
#  'mi!…',
#  'https://t./onrpevzhrw',
#  'today',
#  'make',
#  'america',
#  'great',
#  '!',
#  'vote',
#  'today!',
#  'https://t./mxraxyntjy',
#  'polling',
#  'location.',
#  'going',
#  'make',
#  'america',
#  'great',
#  '!…',
#  'https://t./kpq5ey9vwq',
#  'need',
#  'vote.',
#  'polls!',
#  "let's",
#  'continue',
#  'movement!',
#  'poll',
#  'location:',
#  'https://t./vmudvi1tx1…',
#  'https://t./zgox74ebhw',
#  '#electionday',
#  'https://t./mxraxyntjy',
#  'https://t./fzhoncih21',
#  'watching',
#  'election',
#  'results',
#  'trump',
#  'tower',
#  'manhattan',
#  'family',
#  'friends.',
#  'exciting!',
#  'just',
#  'according',
#  '@cnn:',
#  '"utah',
#  'officials',
#  'report',
#  'voting',
#  'machine',
#  'problems',
#  'entire',
#  'country"',
#  "don't",
#  'let',
#  ',',
#  'getting',
#  'vote',
#  '-',
#  'election',
#  'far',
#  '!',
#  'doing',
#  'time',
#  'left.',
#  'florida!',
#  'time',
#  '#votetrump!',
#  '#ivoted',
#  '#electionnight',
#  'https://t./uztyay1ba6',
#  'watching',
#  'returns',
#  '9:45pm.',
#  '#electionnight',
#  '#maga🇺🇸',
#  'https://t./hfujerzbod',
#  'beautiful',
#  'important',
#  'evening!',
#  'forgotten',
#  'man',
#  'woman',
#  'forgotten',
#  '.',
#  'come',
#  'happy',
#  '241st',
#  'birthday',
#  'u.s.',
#  'marine',
#  'corps!',
#  'thank',
#  'service!!',
#  'https://t./lz2dhrxzo4',
#  'fantastic',
#  'day',
#  'd.c.',
#  'met',
#  'president',
#  'obama',
#  'time.',
#  'really',
#  'good',
#  'meeting,',
#  'great',
#  'chemistry.',
#  'melania',
#  'liked',
#  'mrs.',
#  'o',
#  'lot!',
#  'just',
#  'open',
#  'successful',
#  'presidential',
#  'election.',
#  'professional',
#  'protesters,',
#  'incited',
#  'media,',
#  'protesting.',
#  'unfair!',
#  'love',
#  'fact',
#  'small',
#  'groups',
#  'protesters',
#  'night',
#  'passion',
#  'great',
#  'country.',
#  'come',
#  'proud!',
#  ...]

# %%
# generate DF out of Counter
words_data = pd.DataFrame(Counter(words).most_common(50),
                    columns=['Word', 'Frequency']).set_index('Word')

words_data = words_data.reset_index()

words_data.head(50)
# Out:
#                Word  Frequency
# 0             great       1017
# 1                 …        699
# 2                 ,        529
# 3             &amp;        527
# 4                 !        432
# 5              just        416
# 6                 -        407
# 7             thank        380
# 8                 .        374
# 9            people        337
# 10             fake        280
# 11              big        277
# 12             news        271
# 13        president        270
# 14              new        239
# 15        democrats        229
# 16             u.s.        224
# 17            trump        200
# 18          america        192
# 19           united        179
# 20                “        178
# 21             make        175
# 22            going        174
# 23                (        171
# 24              tax        160
# 25             want        159
# 26            honor        157
# 27          country        153
# 28             time        152
# 29           border        152
# 30         american        146
# 31             good        145
# 32            media        145
# 33            today        142
# 34            north        135
# 35          working        135
# 36            house        132
# 37            doing        130
# 38           states        126
# 39             vote        123
# 40             ....        122
# 41            state        118
# 42       republican        114
# 43  congratulations        113
# 44           today,        112
# 45             like        111
# 46            white        109
# 47          meeting        107
# 48              ...        105
# 49         security        104

# %% [markdown]
# # 3. Sentiment Analysis

# %% [markdown]
# 3.1. Preview the sentiment column.

# %%
# textblob for simplified text processing for sentiment analysis
from textblob import TextBlob
#import re

# Using textblob, sentences classify the polarity of a tweet
def analize_sentiment(tweet):
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'negative'

# %%
# Create a column to show the results of analysis
tweets['Sentiment'] = np.array([ analize_sentiment(tweet) for tweet in tweets['text'] ])
tweets.head(5)
# Out:
#               created_at  favorite_count  retweet_count               source  \
# 2913 2016-11-01 10:31:46           48997          19118  Twitter for Android
# 3321 2016-11-01 11:55:47           34432          14704  Twitter for Android
# 1304 2016-11-01 12:01:11           52775          21172  Twitter for Android
# 4671 2016-11-01 13:35:47           14671           7853   Twitter for iPhone
# 1627 2016-11-01 14:14:09           72273          29281   Twitter for iPhone
#
#                                                    text Sentiment
# 2913  Look at the way Crooked Hillary is handling th...  negative
# 3321  Wow, now leading in @ABC /@washingtonpost Poll...  positive
# 1304  Crooked Hillary should not be allowed to run f...   neutral
# 4671  JOIN ME TOMORROW IN FLORIDA!\n\nMIAMI•12pm\nht...   neutral
# 1627  So terrible that Crooked didn't report she got...  negative

# %% [markdown]
# 3.2 Analyzing the results
# What percentage of reviews are positive, neutral, and negative?

# %%
tweets['Sentiment'].value_counts() / len(tweets)
# Out:
# positive    0.541484
# neutral     0.249410
# negative    0.209106
# Name: Sentiment, dtype: float64

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

labels = ['positive', 'neutral', 'negative']
sizes = [54.148, 24.94, 20.91]

# Create a pie chart
plt.pie( sizes, labels=labels,shadow=False, explode=(0.1,0,0),startangle=90,autopct='%1.1f%%')

# axis('equal') changes limits of x or y axis so that equal increments of x and y have the same length; a circle is circular
plt.axis('equal')

# Plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 3.3 Load in the Sentiment IntensityAnalyzer from Vader and add compound, negative, neutral, and positive scores into the DataFrame.

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sarin_000\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
#VADER to calculate sentiment see if you can correctly predict the hand-tagged sentiment.
compound= []
neg = []
neu = []
pos = []
for tweet in tweets['text']:
    sent = sia.polarity_scores(tweet)
    compound.append(sent['compound'])
    neg.append(sent['neg'])
    neu.append(sent['neu'])
    pos.append(sent['pos'])

# %%
tweets['compound'] = compound
tweets['neg'] = neg
tweets['neu'] = neu
tweets['pos'] = pos

# %% [markdown]
# compound = score/math.sqrt((score**2)+15)

# %%
tweets.head()
# Out:
#               created_at  favorite_count  retweet_count               source  \
# 2913 2016-11-01 10:31:46           48997          19118  Twitter for Android
# 3321 2016-11-01 11:55:47           34432          14704  Twitter for Android
# 1304 2016-11-01 12:01:11           52775          21172  Twitter for Android
# 4671 2016-11-01 13:35:47           14671           7853   Twitter for iPhone
# 1627 2016-11-01 14:14:09           72273          29281   Twitter for iPhone
#
#                                                    text Sentiment  compound  \
# 2913  Look at the way Crooked Hillary is handling th...  negative   -0.7424
# 3321  Wow, now leading in @ABC /@washingtonpost Poll...  positive    0.6239
# 1304  Crooked Hillary should not be allowed to run f...   neutral   -0.5461
# 4671  JOIN ME TOMORROW IN FLORIDA!\n\nMIAMI•12pm\nht...   neutral    0.4981
# 1627  So terrible that Crooked didn't report she got...  negative   -0.5697
#
#         neg    neu    pos
# 2913  0.208  0.792  0.000
# 3321  0.000  0.843  0.157
# 1304  0.150  0.850  0.000
# 4671  0.000  0.756  0.244
# 1627  0.133  0.867  0.000

# %% [markdown]
# 3.4 Store tweet sentiment in y to use as labels and create an appropriate feature matrix, X

# %%
y = tweets['Sentiment']
X = tweets[['compound', 'neg', 'neu', 'pos']]

# %% [markdown]
# 3.5 Fit a model of your choice to predict tweets sentient and cross-validate.

# %%
#ramdomeforest: create bunch of decision tree and got the one the most accurate(majority vote)
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
from sklearn.model_selection import cross_val_score, train_test_split

# %%
rf.fit(X,y)
# Out:
# C:\Users\sarin_000\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#estimate how accurately a predictive model will perform in practice
score=cross_val_score(rf, X, y)
print('Cross Validation of Random Forest is  :{:3f} '.format(score.mean()))
# Out:
# C:\Users\sarin_000\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# Cross Validation of Random Forest is  :0.630182

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=14)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# 3.6 Display the confusion matrix.
# What reviews are difficult to identify?

# %%
conmat = np.array(confusion_matrix(y_test, rf.predict(X_test)))
confusion = pd.DataFrame(conmat, index=['negative', 'neutral', 'positive'],\
                     columns=['Pred neg', 'Pred neutral', 'Pred pos'])

plt.figure(figsize = (6,6))
heat = sns.heatmap(confusion, annot=True, annot_kws={"size": 20},cmap='Blues',fmt='g', cbar=False)
plt.xticks(rotation=0, fontsize=14)
plt.yticks(fontsize=14)
plt.title("Confusion Matrix", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %% [markdown]
# 3.7 Print the classification report.

# %%
print(classification_report(y_test, rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.52      0.50      0.51       387
#      neutral       0.48      0.59      0.53       407
#     positive       0.76      0.70      0.73       985
#
#    micro avg       0.63      0.63      0.63      1779
#    macro avg       0.59      0.60      0.59      1779
# weighted avg       0.65      0.63      0.64      1779

# %% [markdown]
# #The model does ok with positive tweets (the predominant class) but quite poorly with negative and neutral.
# Higher F1 score, the more it is accruate
# Accuracy 정확도 precision 정밀도 recall 재현률
